# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AbdulRehmanA1/FlyrankInternship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/AbdulRehmanA1/FlyrankInternship"
REPO_DIR = "FlyrankInternship"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("../..")

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
# Refresh / Content Opportunity Scoring. I'm picking this lane because my Week 2 notebook already had me build a hand-rule and a readable decision tree to flag pages worth reviewing. That is this lane's job, just formalized: turn a pile of anonymized content pages into a ranked queue an editor can act on, with reasons attached.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd, numpy as np
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print(df.shape[0], "pages,", df["client_id"].nunique(), "clients")
# Out:
# 30000 pages, 32 clients

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
# Decision: which of ~30,000 pages should a content editor review and refresh first, given they can't check every page.
# Who acts: a content editor/reviewer with limited time — they work down a ranked queue instead of guessing.
# Cost of a wrong call: flag a healthy page as urgent → wasted editor hours. Miss a genuinely declining page with real traffic → it keeps losing visibility unnoticed, and that's lost organic revenue for the client.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("decision: which pages to review first | actor: content editor | cost: wasted hours vs missed decline")
# Out:
# decision: which pages to review first | actor: content editor | cost: wasted hours vs missed decline

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
declining_rate = (df["trend_direction"].str.lower() == "down").mean()
low_ctr_candidates = ((df["impressions_90d"] >= 500) & (df["avg_position"] > 0) &
                      (df["avg_position"] <= 20) & (df["ctr"] < 0.5)).sum()
median_impressions = df["impressions_90d"].median()

print(f"Declining rate: {declining_rate:.1%} of all pages")
print(f"Low-CTR visible candidates: {low_ctr_candidates} ({low_ctr_candidates/len(df):.1%} of pages)")
print(f"Median 90-day impressions per page: {median_impressions:.0f}")
# Out:
# Declining rate: 54.2% of all pages
# Low-CTR visible candidates: 9759 (32.5% of pages)
# Median 90-day impressions per page: 731

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
# What I can claim: observed patterns (which pages are declining or under-capturing clicks right now), directional signals (which features associate with decline), and decision-support rankings (a prioritized queue, not a verdict).
# What I never claim: that a refresh will cause recovery (that needs a real experiment, not this data), that I've reverse-engineered Google's ranking algorithm, or that any single score is ground truth — it's a starting point for a human reviewer, not a replacement for one.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Claims allowed: observed / directional / decision-support")
print("Claims never made: causal proof of refresh impact, 'predicting Google'")
# Out:
# Claims allowed: observed / directional / decision-support
# Claims never made: causal proof of refresh impact, 'predicting Google'

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
